# %%
#Data Collection
#○ Goal: Organize your data to streamline the next steps of your
#capstone
#○ Time estimate: 1-2 hours 
#■ Data loading
#■ Data joining
#■ Hint: Data Collection will require the use of the pandas library,
#and functions like read_csv() , depending on the type of data
#you want to read in!
#■ Hint: when adding one dataset to another, make sure you use
#the right function: you might want to merge, join, or
#concatenate. 



# Read in the data and inspect
import pandas as pd
df = pd.read_csv("C:/Users/moon.chu/Documents/Dell_Loaner_12_03_2020/Data Request/Moon/SB/springboard/Traffic_Accident/US_Accidents_Dec20.csv")
df.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
# ...

# %%
# Inspect and see how many california cases we have
df.groupby('State')['City'].count()

# California has 972K cases which is enough for analysis. We will grab only California data and will use it for the analysis. 
cal = df.loc[df['State'] == 'CA']

# hard to see the whole column. let's transpose and display
t_cal=cal.transpose()

# first two columns of data frame with all rows
t_cal.iloc[:, 0:2]
# Out:
#                                                                      728  \
# ID                                                                 A-729
# Source                                                          MapQuest
# TMC                                                                  201
# Severity                                                               3
# Start_Time                                           2016-06-21 10:34:40
# End_Time                                             2016-06-21 11:04:40
# Start_Lat                                                        38.0853
# Start_Lng                                                       -122.233
# End_Lat                                                              NaN
# End_Lng                                                              NaN
# Distance(mi)                                                           0
# Description            Right hand shoulder blocked due to accident on...
# ...

# %%
# take a look at county level just for curiosity
cal.groupby('County')['City'].count()
# Out:
# County
# Alameda             61591
# Alpine                153
# Amador               1342
# Butte                2670
# Calaveras            1572
# Colusa                741
# Contra Costa        32185
# Del Norte             546
# El Dorado            5098
# Fresno              14176
# Glenn                 673
# Humboldt             2243
# Imperial               98
# Inyo                  424
# Kern                15657
# Kings                1890
# Lake                 1972
# Lassen                736
# Los Angeles        314896
# Madera               3597
# Marin                8181
# Mariposa              618
# Mendocino            2875
# Merced               5107
# Modoc                 186
# Mono                  671
# Monterey             9209
# Napa                 4472
# Nevada               3436
# Orange              60419
# Placer               8779
# Plumas                531
# Riverside           50130
# Sacramento          53681
# San Benito           1756
# ...

# %%
# Data Organization
#○ Goal: Create a file structure and add your work to the GitHub repository you’ve created for this project.
#○ Time estimate: 1-2 hours
#■ File structure
#■ GitHub
#■ Hint: the glob library could come in handy here…
#■ Remind yourself of why GitHub is useful. What are the main motivations for making a GitHub repository? 



# Python program to explain os.mkdir() method   
      
# importing os module   
import os  
    
# path  
path = 'C:/Users/moon.chu/Documents/Dell_Loaner_12_03_2020/Data Request/Moon/SB/springboard/Traffic_Accidents2'
    
# Create the directory  
# 'GeeksForGeeks' in  
# '/home / User / Documents'  
try:  
    os.mkdir(path)  
except OSError as error:  
    print(error)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:/Users/moon.chu/Documents/Dell_Loaner_12_03_2020/Data Request/Moon/SB/springboard/Traffic_Accidents2'

# %%
# Data Definition
#○ Goal: Gain an understanding of your data features to inform the
#next steps of your project.
#○ Time estimate: 1-2 hours


#■ Column names
list(cal.columns)
# Out:
# ['ID',
#  'Source',
#  'TMC',
#  'Severity',
#  'Start_Time',
#  'End_Time',
#  'Start_Lat',
#  'Start_Lng',
#  'End_Lat',
#  'End_Lng',
#  'Distance(mi)',
#  'Description',
#  'Number',
#  'Street',
#  'Side',
#  'City',
#  'County',
#  'State',
#  'Zipcode',
#  'Country',
#  'Timezone',
#  'Airport_Code',
#  'Weather_Timestamp',
#  'Temperature(F)',
#  'Wind_Chill(F)',
#  'Humidity(%)',
#  'Pressure(in)',
#  'Visibility(mi)',
#  'Wind_Direction',
#  'Wind_Speed(mph)',
#  'Precipitation(in)',
#  'Weather_Condition',
#  'Amenity',
#  'Bump',
#  'Crossing',
#  'Give_Way',
#  'Junction',
#  'No_Exit',
#  'Railway',
#  'Roundabout',
#  'Station',
#  'Stop',
#  'Traffic_Calming',
#  'Traffic_Signal',
#  'Turning_Loop',
#  'Sunrise_Sunset',
#  'Civil_Twilight',
#  'Nautical_Twilight',
#  'Astronomical_Twilight']

# %%
#■ Data types
#■ Description of the columns

# This is column description in another file
df = pd.read_excel (r'C:/Users/moon.chu/Documents/Dell_Loaner_12_03_2020/Data Request/Moon/SB/springboard/Traffic_Accident/column_names_v2.xlsx')
df.head()
# Out:
#     Attribute                                        Description Nullable
# 0          ID  This is a unique identifier of the accident re...       No
# 1      Source  Indicates source of the accident report (i.e. ...       No
# 2         TMC  A traffic accident may have a Traffic Message ...      Yes
# 3    Severity  Shows the severity of the accident, a number b...       No
# 4  Start_Time  Shows start time of the accident in local time...       No

# %%
# Counts and percents unique values

#Count of unique values for each column
print(cal.nunique())

#Percentage of unique values
cal.nunique()/len(cal)
# Out:
# ID                       972585
# Source                        3
# TMC                          21
# Severity                      4
# Start_Time               829493
# End_Time                 873976
# Start_Lat                276847
# Start_Lng                276725
# End_Lat                  140543
# End_Lng                  143721
# Distance(mi)               5866
# Description              436137
# Number                    27079
# Street                    36680
# Side                          3
# City                       1182
# County                       58
# State                         1
# Zipcode                   62533
# Country                       1
# Timezone                      2
# Airport_Code                141
# Weather_Timestamp        271957
# Temperature(F)              559
# Wind_Chill(F)               388
# Humidity(%)                 100
# Pressure(in)                793
# Visibility(mi)               61
# Wind_Direction               24
# ...

# %%
#■ Ranges of values
#cal.max() - cal.min()

#- Hint: here are some useful questions to ask yourself during this process:
#- Do your column names correspond to what those columns
#store? yes.
#- Check the data types of your columns. Are they sensible?

cal_df=pd.DataFrame(cal)
cal.dtypes
# Out:
# ID                        object
# Source                    object
# TMC                      float64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# ...

# %%
#- Calculate summary statistics for each of your columns, such as mean, median, mode, standard deviation, range, and
#number of unique values. What does this tell you about your data? What do you now need to investigate?
cal.describe()
# Out:
#                  TMC       Severity      Start_Lat      Start_Lng  \
# count  523752.000000  972585.000000  972585.000000  972585.000000
# mean      209.308524       2.255975      35.564095    -119.491106
# std        20.713522       0.469742       2.049160       1.946426
# min       200.000000       1.000000      32.542587    -124.369232
# 25%       201.000000       2.000000      33.967464    -121.594109
# 50%       201.000000       2.000000      34.178920    -118.400819
# 75%       201.000000       3.000000      37.699343    -117.924438
# max       406.000000       4.000000      42.005420    -114.229121
#
#              End_Lat        End_Lng   Distance(mi)        Number  \
# count  448833.000000  448833.000000  972585.000000  2.286270e+05
# mean       35.560920    -119.435477       0.172793  9.076525e+03
# std         2.070667       1.927370       0.703288  2.360027e+04
# min        32.542490    -124.283913       0.000000  1.000000e+00
# ...

# %%
# The data looks suspicious where it has 127F temp and 822 Wind_speed.
cal.loc[cal['Temperature(F)'] > 125,].transpose()
high_temp_100=cal.loc[cal['Temperature(F)'] > 100,]
high_temp_100

# looks like just summer days..
#plotdata=cal['Temperature(F)']

plotdata=high_temp_100['Temperature(F)']
temp=plotdata.head()
temp.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# The data looks suspicious where it has 127F temp and 822 Wind_speed.
cal.loc[cal['Wind_Speed(mph)'] > 822,].transpose() 
high_wind_700=cal.loc[cal['Wind_Speed(mph)'] > 700,]
high_wind_700
#plotdata=cal['Wind_Speed(mph)']
#cal_800.plot(kind="bar")

plotdata=high_wind_700['Wind_Speed(mph)']
temp=plotdata.head()
temp.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#Data Cleaning

#○ Goal: Clean up the data in order to prepare it for the next steps of your project.
#○ Time estimate: 1-2 hours 
#■ NA or missing values
t_cal.iloc[:, 0:10]
# Out:
#                                                                      728  \
# ID                                                                 A-729
# Source                                                          MapQuest
# TMC                                                                  201
# Severity                                                               3
# Start_Time                                           2016-06-21 10:34:40
# End_Time                                             2016-06-21 11:04:40
# Start_Lat                                                        38.0853
# Start_Lng                                                       -122.233
# End_Lat                                                              NaN
# End_Lng                                                              NaN
# Distance(mi)                                                           0
# Description            Right hand shoulder blocked due to accident on...
# ...

# %%
# check all the column that has NA values
cal.isna().any()[lambda x: x]

# count NA value in a column and percentage of NA value
cal.isna().sum()
cal.isna().sum()/len(cal)
# Out:
# ID                       0.000000
# Source                   0.000000
# TMC                      0.461485
# Severity                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Start_Lng                0.000000
# End_Lat                  0.538515
# End_Lng                  0.538515
# Distance(mi)             0.000000
# Description              0.000001
# Number                   0.764929
# Street                   0.000000
# Side                     0.000000
# City                     0.000008
# County                   0.000000
# State                    0.000000
# Zipcode                  0.000374
# Country                  0.000000
# Timezone                 0.000374
# Airport_Code             0.000444
# Weather_Timestamp        0.017970
# Temperature(F)           0.026909
# Wind_Chill(F)            0.498247
# Humidity(%)              0.028452
# Pressure(in)             0.020562
# ...

# %%
#■ Duplicates
#- Hint: don’t forget about the following awesome Python functions for data cleaning, which make life a whole lot easier:
#- loc[] - filter your data by label ## used
#- iloc[] - filter your data by indexes ## used
#- apply() - execute a function across an axis of a DataFrame
#- drop() - drop columns from a DataFrame 


# Drop the columns that has 50% of NA value

new_cal=cal.drop(columns=['End_Lat', 'End_Lng', 'Number','Precipitation(in)'])
new_cal.head()
new_cal.tail()
# Out:
#                 ID Source  TMC  Severity           Start_Time  \
# 4232536  A-4239402   Bing  NaN         2  2019-08-23 18:03:25
# 4232537  A-4239403   Bing  NaN         2  2019-08-23 19:11:30
# 4232538  A-4239404   Bing  NaN         2  2019-08-23 19:00:21
# 4232539  A-4239405   Bing  NaN         2  2019-08-23 19:00:21
# 4232540  A-4239406   Bing  NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat  Start_Lng  Distance(mi)  \
# 4232536  2019-08-23 18:32:01   34.00248 -117.37936         0.543
# 4232537  2019-08-23 19:38:23   32.76696 -117.14806         0.338
# 4232538  2019-08-23 19:28:49   33.77545 -117.84779         0.561
# 4232539  2019-08-23 19:29:42   33.99246 -118.40302         0.772
# 4232540  2019-08-23 19:21:31   34.13393 -117.23092         0.537
#
#                                                Description  ... Roundabout  \
# 4232536                           At Market St - Accident.  ...      False
# ...

# %%
#- is_unique() - check if a column is a unique identifier

# %%
#- Series methods, such as str.contains(), which can be used to check if
#a certain substring occurs in a string of a Series, and str.extract(),
#which can be used to extract capture groups with a certain regex (or
#regular expression ) pattern

#let's change column names that has bracket in case it breaks the data upload
import re
cal_new_new = new_cal.rename(columns=lambda x: re.sub('(\().*?(\))','',x))
cal_new_new.columns                                   

#change the datetime to date

new_cal['Date'] = pd.to_datetime(new_cal['Start_Time'], errors='coerce')
new_cal['Date'] = new_cal['Date'].dt.date
new_cal.head()
                                                      
#numPy methods like .where(), to clean columns. Recall that such methods have the structure: np.where(condition, then, else)
# Out:
#         ID    Source    TMC  Severity           Start_Time  \
# 728  A-729  MapQuest  201.0         3  2016-06-21 10:34:40
# 729  A-730  MapQuest  201.0         3  2016-06-21 10:30:16
# 730  A-731  MapQuest  201.0         2  2016-06-21 10:49:14
# 731  A-732  MapQuest  201.0         3  2016-06-21 10:41:42
# 732  A-733  MapQuest  201.0         2  2016-06-21 10:16:26
#
#                 End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 728  2016-06-21 11:04:40  38.085300 -122.233017           0.0
# 729  2016-06-21 11:16:39  37.631813 -122.084167           0.0
# 730  2016-06-21 11:19:14  37.896564 -122.070717           0.0
# 731  2016-06-21 11:11:42  37.334255 -122.032471           0.0
# 732  2016-06-21 11:04:16  37.250729 -121.910713           0.0
#
#                                            Description  ... Station   Stop  \
# 728  Right hand shoulder blocked due to accident on...  ...   False  False
# 729  Accident on I-880 Northbound at Exit 26 Tennys...  ...   False  False
# ...

# %%
#- DataFrame methods to check for null values --- covered above
